# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanjeevp-07/DeepLearning-Sanjeev-2025-2026/blob/main/Iris_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opendatasets

# %%
import opendatasets as od

dataset_url = "https://www.kaggle.com/datasets/uciml/iris"
od.download(dataset_url)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: Sanjeevp_07
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/uciml/iris
# ...
# 100%|██████████| 3.60k/3.60k [00:00<00:00, 4.21MB/s]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Step 4: Load the dataset
df = pd.read_csv("/content/iris/Iris.csv")

# Step 5: Show first 5 rows
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
